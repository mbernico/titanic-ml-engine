# %%
import datetime
import pandas as pd

from google.cloud import storage

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
import joblib
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder

BUCKET_NAME = 'sandbox-226501-mlengine'

# %%
# Public bucket holding the census data
bucket = storage.Client().bucket(BUCKET_NAME)

# Path to the data inside the public bucket
blob = bucket.blob('titanic-train.csv')
# Download the data
blob.download_to_filename('train.csv')

# Path to the data inside the public bucket
blob = bucket.blob('titanic-test.csv')
# Download the data
blob.download_to_filename('test.csv')

# %%
with open('./train.csv', 'r') as train_data:
    train = pd.read_csv(train_data)
with open('./test.csv', 'r') as train_data:
    test = pd.read_csv(train_data)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
drop_cols = ['PassengerId', 'Name', 'Ticket', 'Cabin']
train.drop(drop_cols, axis=1, inplace=True)
test.drop(drop_cols, axis=1, inplace=True)

# %%
train['Sex'] = train['Sex'].map({'male':1, 'female':0, 1:1, 0:0})
test['Sex'] = train['Sex'].map({'male':1, 'female':0, 1:1, 0:0})

# %%
from sklearn.preprocessing import OneHotEncoder

train = pd.concat([train, pd.get_dummies(train['Embarked'], prefix='Embarked')],axis=1)
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked  Embarked_C  \
# 0           0       3    1  22.0      1      0    7.2500        S           0
# 1           1       1    0  38.0      1      0   71.2833        C           1
# 2           1       3    0  26.0      0      0    7.9250        S           0
# 3           1       1    0  35.0      1      0   53.1000        S           0
# 4           0       3    1  35.0      0      0    8.0500        S           0
# 5           0       3    1   NaN      0      0    8.4583        Q           0
# 6           0       1    1  54.0      0      0   51.8625        S           0
# 7           0       3    1   2.0      3      1   21.0750        S           0
# 8           1       3    0  27.0      0      2   11.1333        S           0
# 9           1       2    0  14.0      1      0   30.0708        C           1
# 10          1       3    0   4.0      1      1   16.7000        S           0
# 11          1       1    0  58.0      0      0   26.5500        S           0
# 12          0       3    1  20.0      0      0    8.0500        S           0
# 13          0       3    1  39.0      1      5   31.2750        S           0
# 14          0       3    0  14.0      0      0    7.8542        S           0
# 15          1       2    0  55.0      0      0   16.0000        S           0
# 16          0       3    1   2.0      4      1   29.1250        Q           0
# 17          1       2    1   NaN      0      0   13.0000        S           0
# 18          0       3    0  31.0      1      0   18.0000        S           0
# 19          1       3    0   NaN      0      0    7.2250        C           1
# 20          0       2    1  35.0      0      0   26.0000        S           0
# 21          1       2    1  34.0      0      0   13.0000        S           0
# 22          1       3    0  15.0      0      0    8.0292        Q           0
# 23          1       1    1  28.0      0      0   35.5000        S           0
# 24          0       3    0   8.0      3      1   21.0750        S           0
# 25          1       3    0  38.0      1      5   31.3875        S           0
# 26          0       3    1   NaN      0      0    7.2250        C           1
# 27          0       1    1  19.0      3      2  263.0000        S           0
# 28          1       3    0   NaN      0      0    7.8792        Q           0
# 29          0       3    1   NaN      0      0    7.8958        S           0
# ..        ...     ...  ...   ...    ...    ...       ...      ...         ...
# 861         0       2    1  21.0      1      0   11.5000        S           0
# 862         1       1    0  48.0      0      0   25.9292        S           0
# 863         0       3    0   NaN      8      2   69.5500        S           0
# 864         0       2    1  24.0      0      0   13.0000        S           0
# 865         1       2    0  42.0      0      0   13.0000        S           0
# 866         1       2    0  27.0      1      0   13.8583        C           1
# 867         0       1    1  31.0      0      0   50.4958        S           0
# 868         0       3    1   NaN      0      0    9.5000        S           0
# 869         1       3    1   4.0      1      1   11.1333        S           0
# 870         0       3    1  26.0      0      0    7.8958        S           0
# 871         1       1    0  47.0      1      1   52.5542        S           0
# 872         0       1    1  33.0      0      0    5.0000        S           0
# 873         0       3    1  47.0      0      0    9.0000        S           0
# 874         1       2    0  28.0      1      0   24.0000        C           1
# 875         1       3    0  15.0      0      0    7.2250        C           1
# 876         0       3    1  20.0      0      0    9.8458        S           0
# 877         0       3    1  19.0      0      0    7.8958        S           0
# 878         0       3    1   NaN      0      0    7.8958        S           0
# 879         1       1    0  56.0      0      1   83.1583        C           1
# 880         1       2    0  25.0      0      1   26.0000        S           0
# 881         0       3    1  33.0      0      0    7.8958        S           0
# 882         0       3    0  22.0      0      0   10.5167        S           0
# 883         0       2    1  28.0      0      0   10.5000        S           0
# 884         0       3    1  25.0      0      0    7.0500        S           0
# 885         0       3    0  39.0      0      5   29.1250        Q           0
# 886         0       2    1  27.0      0      0   13.0000        S           0
# 887         1       1    0  19.0      0      0   30.0000        S           0
# 888         0       3    0   NaN      1      2   23.4500        S           0
# 889         1       1    1  26.0      0      0   30.0000        C           1
# 890         0       3    1  32.0      0      0    7.7500        Q           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# 5             1           0
# 6             0           1
# 7             0           1
# 8             0           1
# 9             0           0
# 10            0           1
# 11            0           1
# 12            0           1
# 13            0           1
# 14            0           1
# 15            0           1
# 16            1           0
# 17            0           1
# 18            0           1
# 19            0           0
# 20            0           1
# 21            0           1
# 22            1           0
# 23            0           1
# 24            0           1
# 25            0           1
# 26            0           0
# 27            0           1
# 28            1           0
# 29            0           1
# ..          ...         ...
# 861           0           1
# 862           0           1
# 863           0           1
# 864           0           1
# 865           0           1
# 866           0           0
# 867           0           1
# 868           0           1
# 869           0           1
# 870           0           1
# 871           0           1
# 872           0           1
# 873           0           1
# 874           0           0
# 875           0           0
# 876           0           1
# 877           0           1
# 878           0           1
# 879           0           0
# 880           0           1
# 881           0           1
# 882           0           1
# 883           0           1
# 884           0           1
# 885           1           0
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 11 columns]

# %%
train['Embarked'] = train['Embarked'].fillna('U')
test['Embarked'] = test['Embarked'].fillna('U')

# %%
le = LabelEncoder()
train['Embarked'] = le.fit_transform(train['Embarked'])
test['Embarked'] = le.transform(test['Embarked'])

# %%
le.classes_
# Out:
# array(['C', 'Q', 'S', 'U'], dtype=object)

# %%
le.transform(['C','Q','S','U'])
# Out:
# array([0, 1, 2, 3])

# %%
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
train_not_null = train[-train['Age'].isnull()]

# %%
X = train_not_null.drop(['Age','Survived'], axis=1)
y = train_not_null['Age']
age_regressor = RandomForestRegressor(n_estimators=100)
age_regressor.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
train.loc[train['Age'].isnull(), 'Age'] = age_regressor.predict(train.loc[train['Age'].isnull()].drop(['Age','Survived'],axis=1))

# %%
test.loc[test['Age'].isnull(), 'Age'] = age_regressor.predict(test.loc[test['Age'].isnull()].drop(['Age'],axis=1))

# %%
median_fare = train['Fare'].median()
test['Fare'].fillna(median_fare, inplace=True)

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
